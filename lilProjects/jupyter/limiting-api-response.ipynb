# %%
# Please note, you will need to apply for an a free api key from alphavantage to use this api
import requests
import json
stock_api = 'https://www.alphavantage.co/query?function=TIME_SERIES_WEEKLY&symbol=IBM&apikey=<add api key here>'
market_response = requests.get(stock_api, params=params)
data = market_response.json()
data
# Out:
# {'Meta Data': {'1. Information': 'Weekly Prices (open, high, low, close) and Volumes',
#   '2. Symbol': 'IBM',
#   '3. Last Refreshed': '2024-11-22',
#   '4. Time Zone': 'US/Eastern'},
#  'Weekly Time Series': {'2024-11-22': {'1. open': '207.0000',
#    '2. high': '227.2000',
#    '3. low': '205.3701',
#    '4. close': '222.9700',
#    '5. volume': '21386866'},
#   '2024-11-15': {'1. open': '214.4000',
#    '2. high': '215.4100',
#    '3. low': '204.0700',
#    '4. close': '204.9900',
#    '5. volume': '19438346'},
#   '2024-11-08': {'1. open': '207.6500',
#    '2. high': '216.7000',
#    '3. low': '205.5700',
#    '4. close': '213.7200',
#    '5. volume': '15846890'},
#   '2024-11-01': {'1. open': '215.5000',
#    '2. high': '216.2500',
#    '3. low': '203.5100',
#    '4. close': '208.2500',
#    '5. volume': '26467891'},
#   '2024-10-25': {'1. open': '231.2100',
#    '2. high': '233.3400',
#    '3. low': '214.3850',
#    '4. close': '214.6700',
#    '5. volume': '31380820'},
# ...

# %%
 weekly_data = data["Weekly Time Series"]
new_list = []

# Limit the number of items to 10
for i, (date, values) in enumerate(weekly_data.items()):
	if i < 10:
		new_list.append({date: values['1. open']})
	else:
		break

print(new_list)
# Out:
# [{'2024-11-21': '207.0000'}, {'2024-11-15': '214.4000'}, {'2024-11-08': '207.6500'}, {'2024-11-01': '215.5000'}, {'2024-10-25': '231.2100'}, {'2024-10-18': '233.5700'}, {'2024-10-11': '225.3800'}, {'2024-10-04': '220.6500'}, {'2024-09-27': '218.0000'}, {'2024-09-20': '215.8800'}]
